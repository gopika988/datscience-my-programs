# %% [markdown]
# <a href="https://colab.research.google.com/github/gopika988/datscience-my-programs/blob/main/graph1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=[20,55,60,50]
plt.plot(x,y)
plt.title("simple graph")
plt.ylabel("yaxis")
plt.xlabel("xaxis")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
y=[5,3,4,5,6,7,2,8,9]
plt.plot(y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
a=[1,2,3,4,5]
b=[0,0.6,0.2,15,10,8,16,21]
plt.plot(a)
plt.plot(b,"or")
plt.plot(list(range(0,22,3)))
plt.xlabel('Day ->')
plt.ylabel('Temp ->')
c=[4,2,6,8,3,20,13,15]
plt.plot(c,label='4 the Rep')
ax=plt.gca()
ax.spines['right'].set-visible(False)
ax.spines['top'].set-visible(False)
ax.spines['left'].set-bounds(-3,40)
plt.xticks(list(range-3,10))
plt.yticks(list(range(-3,20,3)))
ax.legend(['1 st Rep','2nd Rep','3rd Rep'])
plt.annotate('Temperature V / s Day')
plt.title('All Features Discussed')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-97200a06ab71> in <module>()
#       9 plt.plot(c,label='4 the Rep')
#      10 ax=plt.gca()
# ---> 11 ax.spines['right'].set-visible(False)
#      12 ax.spines['top'].set-visible(False)
#      13 ax.spines['left'].set-bounds(-3,40)
#
# NameError: name 'visible' is not defined
